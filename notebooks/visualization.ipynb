# %%
#import necessary libraries
import pandas as pd
from bokeh.plotting import figure, show, output_notebook
import numpy as np
from bokeh.models import ColumnDataSource
from math import pi


#load the cleaned data
building_data_cp = pd.read_csv('../data/processed/rentsafeto_cleaned.csv')
print(building_data_cp.head())
# Out:
#    _id      RSN  YEAR REGISTERED  YEAR BUILT  YEAR EVALUATED PROPERTY TYPE  \
# 0    1  4154961             2017        1960            2024       PRIVATE
# 1    2  4154960             2017        1967            2025       PRIVATE
# 2    3  4154960             2017        1967            2023       PRIVATE
# 3    4  4154939             2017        1965            2025       PRIVATE
# 4    5  4154939             2017        1965            2023       PRIVATE
#
#              WARDNAME    SITE ADDRESS  CONFIRMED STOREYS  CONFIRMED UNITS  \
# 0  Toronto-St. Paul's   54 RAGLAN AVE                  4               16
# 1  Toronto-St. Paul's  100 RAGLAN AVE                 13              230
# 2  Toronto-St. Paul's  100 RAGLAN AVE                 13              230
# 3  Toronto-St. Paul's  105 RAGLAN AVE                  6               34
# 4  Toronto-St. Paul's  105 RAGLAN AVE                  6               34
#
#    ... VITAL SERVICE PLAN  ELECTRICAL SAFETY PLAN  STATE OF GOOD REPAIR PLAN  \
# 0  ...                  3                       3                          3
# 1  ...                  2                       3                          3
# 2  ...                  1                       1                          1
# 3  ...                  3                       1                          3
# 4  ...                  3                       3                          3
#
#    TENANT SERVICE REQUEST LOG   GRID  LATITUDE  LONGITUDE       X        Y  \
# 0                           3  S1229        43        -79  311191  4838067
# 1                           3  S1229        43        -79  311159  4838169
# 2                           3  S1229        43        -79  311159  4838169
# 3                           3  S1229        43        -79  311192  4838258
# 4                           3  S1229        43        -79  311192  4838258
#
#   BUILDING SCORE CATEGORY
# 0               Excellent
# 1                    Good
# 2                    Good
# 3                    Good
# 4               Excellent
#
# [5 rows x 54 columns]
